# %%
# %load_ext autoreload
# %autoreload 2

import warnings
import pandas as pd
import numpy as np
import os
import sys # error msg, add the modules
import operator # sorting
from math import *
import matplotlib.pyplot as plt

sys.path.append('../')

warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

import prep
from warp import *

# %%
trace_file = 'trace.csv'
metrics_file = 'metrics.csv'

# read trace and metrics into dataframe, from generated trace file
df_kernel_trace, df_metrics = prep.Prep_trace_metrics(trace_file, metrics_file)

# %%
unique_kerns = []
for index, kenname in enumerate(df_kernel_trace.Name.unique()):
    if index > 0 and 'memcpy' not in kenname:
        head = kenname.split('(')[0]
        if '<' in head:
            head = head.split('<')[0]
        #print head
    
        if 'void' in head:
            head = head.split(' ')
            #print head[1]
            head = head[1]
            
        if head not in unique_kerns:
            unique_kerns.append(head)
            print head
# Out:
# histogram64Kernel
# mergeHistogram64Kernel
# histogram256Kernel
# mergeHistogram256Kernel

# %%
target_kern_name = 'histogram64Kernel'
sass_result = target_kern_name + '.sm_52.sass.result'
kernel_stat_out ='kernelStat_' + target_kern_name + '.csv'

out_columns = prep.init_df_columns(df_metrics)
df_kern = pd.DataFrame(columns=out_columns)

# current kernel trace
df_current = prep.GenCurKernInfo(df_kernel_trace, df_metrics,target_kern_name, out_columns)
# add current trace
df_kern = df_kern.append(df_current, ignore_index=True)

warp_inst = WarpInst()
warp_inst.run(df_kern, sass_result)

df_kern.insert(1, 'm2c_ratio', warp_inst.mem_clks / warp_inst.cmp_clks)
df_kern.to_csv(kernel_stat_out, index=False, encoding='utf-8')
df_kern
# Out:
# LDG (global load) clocks (per warp) 		 = 11700.0
# STG (global store) clocks (per warp) 		 = 19.0
# LDS (shared memory load) clocks (per warp) 	 = 26.0
# STS (shared memory store) clocks (per warp) 	 = 19.0
# => Memory inst. (per warp) 			 = 11764.0 (clocks)
#
# Integer inst. (per warp) 		 = 1290.0 (clocks)
# FP32 inst. (per warp) 			 = 0.0 (clocks)
# FP64 inst. (per warp) 			 = 0.0 (clocks)
# Compute load store inst. (per warp) 	 = 330.0 (clocks)
# => Compute inst. (per warp) 		 = 1620.0 (clocks)
#
# Memory Intensive : mem / cmp = 7.26172839506
#            kern_name  m2c_ratio  duration_ms  gridx  gridy  gridz   blkx  \
# 0  histogram64kernel   7.261728     0.040416   64.0    1.0    1.0  256.0
#
#    blky  blkz  reg_per_thread  ...   l2_atomic_transactions  \
# 0   1.0   1.0            15.0  ...                        0
#
#   sysmem_utilization ecc_throughput sysmem_read_utilization  \
# 0            Low (1)    0.000000B/s                Idle (0)
#
#   sysmem_write_utilization eligible_warps_per_cycle flop_sp_efficiency  \
# 0                  Low (1)                 0.323291          0.000000%
#
#   flop_dp_efficiency shared_utilization   NaN
# 0          0.000000%            Low (1)  None
#
# [1 rows x 125 columns]

# %%
target_kern_name = 'mergeHistogram64Kernel'
sass_result = target_kern_name + '.sm_52.sass.result'
kernel_stat_out ='kernelStat_' + target_kern_name + '.csv'

out_columns = prep.init_df_columns(df_metrics)
df_kern = pd.DataFrame(columns=out_columns)

# current kernel trace
df_current = prep.GenCurKernInfo(df_kernel_trace, df_metrics,target_kern_name, out_columns)
# add current trace
df_kern = df_kern.append(df_current, ignore_index=True)

warp_inst = WarpInst()
warp_inst.run(df_kern, sass_result)

df_kern.insert(1, 'm2c_ratio', warp_inst.mem_clks / warp_inst.cmp_clks)
df_kern.to_csv(kernel_stat_out, index=False, encoding='utf-8')
df_kern
# Out:
# LDG (global load) clocks (per warp) 		 = 11700.0
# STG (global store) clocks (per warp) 		 = 19.0
# LDS (shared memory load) clocks (per warp) 	 = 26.0
# STS (shared memory store) clocks (per warp) 	 = 19.0
# => Memory inst. (per warp) 			 = 11764.0 (clocks)
#
# Integer inst. (per warp) 		 = 1290.0 (clocks)
# FP32 inst. (per warp) 			 = 0.0 (clocks)
# FP64 inst. (per warp) 			 = 0.0 (clocks)
# Compute load store inst. (per warp) 	 = 330.0 (clocks)
# => Compute inst. (per warp) 		 = 1620.0 (clocks)
#
# Memory Intensive : mem / cmp = 7.26172839506
#                 kern_name  m2c_ratio  duration_ms  gridx  gridy  gridz   blkx  \
# 0  mergehistogram64kernel   7.261728     0.041888   64.0    1.0    1.0  256.0
#
#    blky  blkz  reg_per_thread  ...   l2_atomic_transactions  \
# 0   1.0   1.0            15.0  ...                        0
#
#   sysmem_utilization ecc_throughput sysmem_read_utilization  \
# 0            Low (1)    0.000000B/s                Idle (0)
#
#   sysmem_write_utilization eligible_warps_per_cycle flop_sp_efficiency  \
# 0                  Low (1)                 0.322960          0.000000%
#
#   flop_dp_efficiency shared_utilization   NaN
# 0          0.000000%            Low (1)  None
#
# [1 rows x 125 columns]

# %%
target_kern_name = 'histogram256Kernel'
sass_result = target_kern_name + '.sm_52.sass.result'
kernel_stat_out ='kernelStat_' + target_kern_name + '.csv'

out_columns = prep.init_df_columns(df_metrics)
df_kern = pd.DataFrame(columns=out_columns)

# current kernel trace
df_current = prep.GenCurKernInfo(df_kernel_trace, df_metrics,target_kern_name, out_columns)
# add current trace
df_kern = df_kern.append(df_current, ignore_index=True)

warp_inst = WarpInst()
warp_inst.run(df_kern, sass_result)

df_kern.insert(1, 'm2c_ratio', warp_inst.mem_clks / warp_inst.cmp_clks)
df_kern.to_csv(kernel_stat_out, index=False, encoding='utf-8')
df_kern
# Out:
# LDG (global load) clocks (per warp) 		 = 41600.0
# STG (global store) clocks (per warp) 		 = 19.0
# LDS (shared memory load) clocks (per warp) 	 = 2964.0
# STS (shared memory store) clocks (per warp) 	 = 2166.0
# => Memory inst. (per warp) 			 = 46749.0 (clocks)
#
# Integer inst. (per warp) 		 = 65535.0 (clocks)
# FP32 inst. (per warp) 			 = 0.0 (clocks)
# FP64 inst. (per warp) 			 = 0.0 (clocks)
# Compute load store inst. (per warp) 	 = 19395.0 (clocks)
# => Compute inst. (per warp) 		 = 84930.0 (clocks)
#
# Compute Intensive : cmp / mem = 1.81672335237
#             kern_name  m2c_ratio  duration_ms  gridx  gridy  gridz   blkx  \
# 0  histogram256kernel   0.550442       0.0144  256.0    1.0    1.0  256.0
#
#    blky  blkz  reg_per_thread  ...   l2_atomic_transactions  \
# 0   1.0   1.0            15.0  ...                        0
#
#   sysmem_utilization ecc_throughput sysmem_read_utilization  \
# 0            Low (1)    0.000000B/s                Idle (0)
#
#   sysmem_write_utilization eligible_warps_per_cycle flop_sp_efficiency  \
# 0                  Low (1)                 2.288928          0.000000%
#
#   flop_dp_efficiency shared_utilization   NaN
# 0          0.000000%            Low (1)  None
#
# [1 rows x 125 columns]

# %%
target_kern_name = 'mergeHistogram256Kernel'
sass_result = target_kern_name + '.sm_52.sass.result'
kernel_stat_out ='kernelStat_' + target_kern_name + '.csv'

out_columns = prep.init_df_columns(df_metrics)
df_kern = pd.DataFrame(columns=out_columns)

# current kernel trace
df_current = prep.GenCurKernInfo(df_kernel_trace, df_metrics,target_kern_name, out_columns)
# add current trace
df_kern = df_kern.append(df_current, ignore_index=True)

warp_inst = WarpInst()
warp_inst.run(df_kern, sass_result)

df_kern.insert(1, 'm2c_ratio', warp_inst.mem_clks / warp_inst.cmp_clks)
df_kern.to_csv(kernel_stat_out, index=False, encoding='utf-8')
df_kern
# Out:
# LDG (global load) clocks (per warp) 		 = 650.0
# STG (global store) clocks (per warp) 		 = 19.0
# LDS (shared memory load) clocks (per warp) 	 = 26.0
# STS (shared memory store) clocks (per warp) 	 = 19.0
# => Memory inst. (per warp) 			 = 714.0 (clocks)
#
# Integer inst. (per warp) 		 = 315.0 (clocks)
# FP32 inst. (per warp) 			 = 0.0 (clocks)
# FP64 inst. (per warp) 			 = 0.0 (clocks)
# Compute load store inst. (per warp) 	 = 75.0 (clocks)
# => Compute inst. (per warp) 		 = 390.0 (clocks)
#
# Memory Intensive : mem / cmp = 1.83076923077
#                  kern_name  m2c_ratio  duration_ms  gridx  gridy  gridz  \
# 0  mergehistogram256kernel   1.830769       0.0144  256.0    1.0    1.0
#
#     blkx  blky  blkz  reg_per_thread  ...   l2_atomic_transactions  \
# 0  256.0   1.0   1.0            15.0  ...                        0
#
#   sysmem_utilization ecc_throughput sysmem_read_utilization  \
# 0            Low (1)    0.000000B/s                Idle (0)
#
#   sysmem_write_utilization eligible_warps_per_cycle flop_sp_efficiency  \
# 0                  Low (1)                 2.183389          0.000000%
#
#   flop_dp_efficiency shared_utilization   NaN
# 0          0.000000%            Low (1)  None
#
# [1 rows x 125 columns]
